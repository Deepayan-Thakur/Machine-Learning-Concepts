# %% [markdown]
# # Goal
#
# Apply everything learned so far in one coherent analysis.

# %% [markdown]
# # Problem Statement
#
# ## Mini Project: Titanic Survival Analysis
#
# Goal: Identify patterns and factors affecting passenger survival.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load Data
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
# Clean Data
df["Age"].fillna(df["Age"].median(), inplace=True)
df["Embarked"].fillna(df["Embarked"].mode()[0], inplace=True)
df.drop(columns=["Cabin"], inplace=True)
# Out:
# C:\Users\DEEPAYAN\AppData\Local\Temp\ipykernel_19572\337317601.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].median(), inplace=True)
# C:\Users\DEEPAYAN\AppData\Local\Temp\ipykernel_19572\337317601.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Feature Insights
df.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.groupby("Pclass")["Survived"].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# # Visualization

# %%
import seaborn as sns
sns.barplot(x="Sex", y="Survived", data=df)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### Key Insights
# - Females had higher survival rates
# - Higher passenger class increased survival
# - Age influenced survival non-linearly
